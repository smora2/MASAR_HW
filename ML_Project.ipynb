# %% [markdown]
# <a href="https://colab.research.google.com/github/smora2/MASAR_HW/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apple quality
# ### SAMAHER YOUNUS

# %% [markdown]
# Apple quality, discover the world of fruits
#
# The source: (https://www.kaggle.com/datasets/nelgiriyewithana/apple-quality/data)

# %% [markdown]
# ## 1- Data Cleaning

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

s = pd.read_csv('/content/apple_quality.csv')
df = s

# %%
s.head(10)
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5   5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 6   6.0  1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
# 7   7.0 -1.995462 -0.428958   1.530644    -0.742972   0.158834  0.974438
# 8   8.0 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 9   9.0 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
s.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
s.dtypes
# Out:
# A_id           float64
# Size           float64
# Weight         float64
# Sweetness      float64
# Crunchiness    float64
# Juiciness      float64
# Ripeness       float64
# Acidity         object
# Quality         object
# dtype: object

# %%
s.isnull().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
s_new = s.dropna()

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
s_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 312.5+ KB

# %%
s.sum()
# Out:
# <ipython-input-52-1597a9ac297c>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   s.sum()
# A_id                                                   7998000.0
# Size                                                -2012.058519
# Weight                                              -3958.186178
# Sweetness                                           -1881.914079
# Crunchiness                                          3941.911615
# Juiciness                                            2048.471874
# Ripeness                                             1993.109712
# Acidity        -0.491590483-0.7228093672.6216364730.790723217...
# dtype: object

# %%
s.Size.max()
# Out:
# 6.406366899

# %%
s.duplicated().sum()
# Out:
# 0

# %%
s.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
plt.figure(figsize=(20, 5))

sns.boxplot(s=s.drop('A_id', axis=1), orient='v', palette='Set2')

plt.xlabel('Columns')
plt.ylabel('Values')
plt.title('Boxplot for Each Column')
plt.show()

# %% [markdown]
# ### Data Processing

# %%
columns_To_Normalize = ['A_id',	'Size',	'Weight',	'Sweetness',	'Crunchiness',	'Juiciness',	'Ripeness']

scaler = StandardScaler()
s[columns_To_Normalize] = scaler.fit_transform(s[columns_To_Normalize])
s
# Out:
#           A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# 0    -1.731618 -1.798424 -0.950373   2.993421    -1.424150   0.690545
# 1    -1.730752 -0.359060 -1.154404   2.127698     0.429746   0.176767
# 2    -1.729886  0.109445 -0.225759  -0.652507    -0.946892   1.205422
# 3    -1.729020 -0.079977 -0.800146   0.923916    -0.772399   1.619575
# 4    -1.728154  0.968573 -0.191640   0.044164    -1.096894   1.305025
# ...        ...       ...       ...        ...          ...        ...
# 3996  1.729020  0.108878  1.834105   0.137124    -1.159058  -0.252634
# 3997  1.729886 -1.105655 -0.716904  -1.013784    -0.234036   0.874379
# 3998  1.730752 -1.818112 -0.492908   1.459901    -0.845446   0.854549
# 3999  1.731618  0.405409 -0.453071   0.304496    -1.525439   0.390954
# 4000       NaN       NaN       NaN        NaN          NaN        NaN
#
#       Ripeness                            Acidity Quality
# 0    -0.089872                       -0.491590483    good
# ...

# %%
min_max_scaler = MinMaxScaler()
s[columns_To_Normalize] = min_max_scaler.fit_transform(s[columns_To_Normalize])
s
# Out:
#          A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# 0     0.00000  0.234669  0.358370   0.922484     0.368781   0.585819
# 1     0.00025  0.439331  0.333107   0.795706     0.558928   0.511408
# 2     0.00050  0.505948  0.448092   0.388567     0.417732   0.660388
# 3     0.00075  0.479014  0.376971   0.619422     0.435629   0.720370
# 4     0.00100  0.628107  0.452317   0.490589     0.402347   0.674814
# ...       ...       ...       ...        ...          ...        ...
# 3996  0.99925  0.505867  0.703146   0.504203     0.395971   0.449218
# 3997  0.99950  0.333173  0.387278   0.335661     0.490846   0.612443
# 3998  0.99975  0.231869  0.415014   0.697913     0.428137   0.609571
# 3999  1.00000  0.548031  0.419946   0.528713     0.358392   0.542429
# 4000      NaN       NaN       NaN        NaN          NaN        NaN
#
#       Ripeness                            Acidity Quality
# 0     0.472770                       -0.491590483    good
# ...

# %%
s.head()
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0  0.00000  0.234669  0.358370   0.922484     0.368781   0.585819  0.472770
# 1  0.00025  0.439331  0.333107   0.795706     0.558928   0.511408  0.513807
# 2  0.00050  0.505948  0.448092   0.388567     0.417732   0.660388  0.444693
# 3  0.00075  0.479014  0.376971   0.619422     0.435629   0.720370  0.187052
# 4  0.00100  0.628107  0.452317   0.490589     0.402347   0.674814  0.348084
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
sampleData = {'Size': [-3.970049,-1.195217,-0.292024,-0.292024,1.364217],
        'Weight': [-2.512336,-2.839257,-1.351282,-2.271627,-1.296612]}

sampleDf = pd.DataFrame(sampleData)

print("Original DataFrame:")
print(sampleDf)

sampleDf['Compactness'] = (4 * 3.14159 * sampleDf['Size']) / (sampleDf['Weight'] ** 2)

print("\nDataFrame with Compactness:")
print(sampleDf)
# Out:
# Original DataFrame:
#        Size    Weight
# 0 -3.970049 -2.512336
# 1 -1.195217 -2.839257
# 2 -0.292024 -1.351282
# 3 -0.292024 -2.271627
# 4  1.364217 -1.296612
#
# DataFrame with Compactness:
#        Size    Weight  Compactness
# 0 -3.970049 -2.512336    -7.904054
# 1 -1.195217 -2.839257    -1.863146
# 2 -0.292024 -1.351282    -2.009722
# 3 -0.292024 -2.271627    -0.711138
# 4  1.364217 -1.296612    10.197011

# %% [markdown]
# ## 3- Data Visualization

# %%
sDiagram = s.drop('A_id', axis=1)

# %%
sDiagram.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0  0.234669  0.358370   0.922484     0.368781   0.585819  0.472770
# 1  0.439331  0.333107   0.795706     0.558928   0.511408  0.513807
# 2  0.505948  0.448092   0.388567     0.417732   0.660388  0.444693
# 3  0.479014  0.376971   0.619422     0.435629   0.720370  0.187052
# 4  0.628107  0.452317   0.490589     0.402347   0.674814  0.348084
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %% [markdown]
# ### Scatterplot

# %%
sns.FacetGrid(sDiagram, hue ="Quality", height = 6).map(plt.scatter, 'Sweetness' ,'Acidity').add_legend()
plt.suptitle("Apple taste chart according to its sweetness or sourness", y=1.02)
# Out:
# Text(0.5, 1.02, 'Apple taste chart according to its sweetness or sourness')

# %%
sns.pairplot(sDiagram, hue="Quality", palette="husl", markers=["o", "s", "D"])
plt.suptitle("Quality pairwise dataset", y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)
# ...

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 1)
sns.boxplot(x="Quality", y="Sweetness", s=sDiagram)
plt.subplot(2, 2, 2)
sns.boxplot(x="Quality", y="Crunchiness", s=sDiagram)
plt.subplot(2, 2, 3)
sns.boxplot(x="Quality", y="Juiciness", s=sDiagram)
plt.subplot(2, 2, 4)
sns.boxplot(x="Quality", y="Ripeness", s=sDiagram)
plt.subplot(2, 2, 5)
sns.boxplot(x="Quality", y="Acidity", s=sDiagram)
plt.suptitle("Boxplots of quality features by apple type", y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-a970c22d940d> in <cell line: 3>()
#       1 plt.figure(figsize=(15, 6))
#       2 plt.subplot(2, 2, 1)
# ----> 3 sns.boxplot(x="Quality", y="Sweetness", s=sDiagram)
#       4 plt.subplot(2, 2, 2)
#       5 sns.boxplot(x="Quality", y="Crunchiness", s=sDiagram)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1594 ):
#    1595
# -> 1596     p = _CategoricalPlotter(
#    1597         data=data,
#    1598         variables=dict(x=x, y=y, hue=hue),
#
# ...

# %% [markdown]
# ### Violin plot

# %%
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 1)
sns.boxplot(x="Quality", y="Sweetness", s=sDiagram)
plt.subplot(2, 2, 2)
sns.boxplot(x="Quality", y="Crunchiness", s=sDiagram)
plt.subplot(2, 2, 3)
sns.boxplot(x="Quality", y="Juiciness", s=sDiagram)
plt.subplot(2, 2, 4)
sns.boxplot(x="Quality", y="Ripeness", s=sDiagram)
plt.subplot(2, 2, 5)
sns.boxplot(x="Quality", y="Acidity", s=sDiagram)
plt.suptitle("Boxplots of quality features by apple type", y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-a970c22d940d> in <cell line: 3>()
#       1 plt.figure(figsize=(15, 6))
#       2 plt.subplot(2, 2, 1)
# ----> 3 sns.boxplot(x="Quality", y="Sweetness", s=sDiagram)
#       4 plt.subplot(2, 2, 2)
#       5 sns.boxplot(x="Quality", y="Crunchiness", s=sDiagram)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1594 ):
#    1595
# -> 1596     p = _CategoricalPlotter(
#    1597         data=data,
#    1598         variables=dict(x=x, y=y, hue=hue),
#
# ...

# %% [markdown]
# ### Correlation Matrix

# %%
correlation_matrix = sDiagram.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Correlation Matrix of seeds features")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-6ea0b96070ca> in <cell line: 1>()
# ----> 1 correlation_matrix = sDiagram.corr()
#       2 sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
#       3 plt.title("Correlation Matrix of seeds features")
#       4 plt.show()
#
# AttributeError: 'int' object has no attribute 'corr'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report



# Assuming 'seedType' is the label and the rest are features
X = df[['Sweetness', 'Acidity']]
y = df['Quality']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Create a logistic regression model
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_rep)

# Get the coefficients
coefficients = model.coef_[0]

# Print the coefficients for each feature
for feature, coef in zip(X.columns, coefficients):
    print(f'{feature}: {coef}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-eb3833e44ced> in <cell line: 19>()
#      17
#      18 # Train the model
# ---> 19 model.fit(X_train, y_train)
#      20
#      21 # Make predictions on the test set
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...
